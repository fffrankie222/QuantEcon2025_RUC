# %%
import pandas as pd

filename='class_math.xlsx'

df=pd.read_excel(filename,header=2)

cond=df['序号'].notnull()
df=df[cond]

df=df.astype({'学号':int})

var_list=['序号', '学号', '姓名', '班级']

df=df[var_list]
# Out:
# /home/hmai/anaconda3/envs/work/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df['班级'].replace('\d\d\d\d|级|\d|班','',regex=True).value_counts()
# Out:
# 班级
# 经济学-数学双学位实验               15
# “经济学-数学”双学士学位复合型人才培养项目     6
# 经济学                        1
# 经济学数学双学位实验                 1
# 明德环境“经济学-科学”拔尖人才实验         1
# Name: count, dtype: int64

# %%
df_groups=df.sample(frac = 1,random_state=202502)

df_groups['number'] = range(len(df_groups))

n_members=4

df_groups['group']=df_groups['number']//n_members+1

# %%
df_groups.sort_values(by='group')
# Out:
#       序号          学号    姓名                            班级  number  group
# 18  18.0  2022202681   曹越晰              2022经济学-数学双学位实验班       0      1
# 21  21.0  2022202710   邓双贤              2022经济学-数学双学位实验班       1      1
# 5    5.0  2022201343   刘倡源  2022“经济学-数学”双学士学位复合型人才培养项目1班       2      1
# 22  22.0  2022202743   马瑜梓              2022经济学-数学双学位实验班       3      1
# 8    8.0  2022201412   徐子禾  2022“经济学-数学”双学士学位复合型人才培养项目1班       4      2
# 1    1.0  2021200657   梁艺高                     2021经济学1班       5      2
# 23  23.0  2022202747   郭立为              2022经济学-数学双学位实验班       6      2
# 4    4.0  2021202449   曹馨元     2021明德环境“经济学-科学”拔尖人才实验班1班       7      2
# 7    7.0  2022201372   胡熙媛  2022“经济学-数学”双学士学位复合型人才培养项目1班      10      3
# 10  10.0  2022201480   梁泓铭  2022“经济学-数学”双学士学位复合型人才培养项目1班      11      3
# 6    6.0  2022201353   俞项天  2022“经济学-数学”双学士学位复合型人才培养项目1班       8      3
# 15  15.0  2022202654   江孟书              2022经济学-数学双学位实验班       9      3
# 9    9.0  2022201462  欧阳语博  2022“经济学-数学”双学士学位复合型人才培养项目1班      12      4
# 11  11.0  2022202610   程忆楠              2022经济学-数学双学位实验班      13      4
# 14  14.0  2022202625   陈尚祺              2022经济学-数学双学位实验班      14      4
# 24  24.0  2022202763   谢丽媛              2022经济学-数学双学位实验班      15      4
# 17  17.0  2022202672   邵远平              2022经济学-数学双学位实验班      16      5
# 16  16.0  2022202655   方国圳              2022经济学-数学双学位实验班      17      5
# 2    2.0  2021200691   滕明阳              2022经济学-数学双学位实验班      18      5
# 20  20.0  2022202709   李馨怡              2022经济学-数学双学位实验班      19      5
# 19  19.0  2022202692   唐汇宸              2022经济学-数学双学位实验班      22      6
# 3    3.0  2021201687   朱堃琳             2021经济学数学双学位实验班1班      20      6
# 13  13.0  2022202620   王成林              2022经济学-数学双学位实验班      21      6
# 12  12.0  2022202619   张沛渊              2022经济学-数学双学位实验班      23      6
