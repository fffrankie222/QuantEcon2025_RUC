# %%
import pandas as pd

filename='class_eng.xlsx'

df=pd.read_excel(filename,header=2)

cond=df['序号'].notnull()
df=df[cond]

df=df.astype({'学号':int})

var_list=['序号', '学号', '姓名', '班级']

df=df[var_list]
# Out:
# /home/hmai/anaconda3/envs/work/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df['班级'].replace('\d\d\d\d|级|\d|班','',regex=True).value_counts()
# Out:
# 班级
# 经济学类           12
# 经济学             4
# 经济学-数学双学位实验     1
# 国际经济与贸易         1
# 本科金融工程          1
# Name: count, dtype: int64

# %%
df_groups=df.sample(frac = 1,random_state=202502)

df_groups['number'] = range(len(df_groups))

n_members=4

df_groups['group']=df_groups['number']//n_members+1

# %%
df_groups.sort_values(by='group')
# Out:
#       序号          学号   姓名                班级  number  group
# 18  18.0  2023200744  秦梓珂        2023经济学类4班       0      1
# 5    5.0  2021200697  柳任时         2021经济学3班       1      1
# 19  19.0  2023200793  江智睿        2023经济学类1班       2      1
# 8    8.0  2022202560  卢俊然        2022经济学类4班       3      1
# 15  15.0  2023200584  张亦佳        2023经济学类4班       4      2
# 16  16.0  2023200660   段毅        2023经济学类4班       5      2
# 6    6.0  2021200715  李嘉乐         2021经济学2班       6      2
# 10  10.0  2022202650  李昕珏        2022经济学类2班       7      2
# 1    1.0  2021200567  赵一铭         2021经济学1班      11      3
# 11  11.0  2022202670  宋晓明        2022经济学类2班      10      3
# 9    9.0  2022202622  薛佳易        2022经济学类2班       9      3
# 7    7.0  2022200230  妙含笑      2022级本科金融工程班       8      3
# 17  17.0  2023200739  钟梓洋        2023经济学类3班      12      4
# 14  14.0  2023200579  王锦川        2023经济学类3班      13      4
# 2    2.0  2021200631  方至成  2021经济学-数学双学位实验班      14      4
# 4    4.0  2021200641  林亦隆         2021经济学3班      15      4
# 3    3.0  2021200639  邱丹绮     2021国际经济与贸易1班      16      5
# 13  13.0  2022202751  张雷臻        2022经济学类3班      17      5
# 12  12.0  2022202690  王煜阳        2022经济学类4班      18      5
